# %%
# Download Zip file & Notebooks to Jupyter

import requests


rootlocation = "https://github.com/ajhenley/DataBootCampIntro/raw/master/"
location = rootlocation + "datasets.zip"
otherlocations = ['01 - Basic Python.ipynb', '02 - Explore Data.ipynb', '03 - Data Manipulation.ipynb']

r = requests.get(location, allow_redirects=True)
open('datasets.zip', 'wb').write(r.content)

for loc in otherlocations:
     location = rootlocation + loc
     r = requests.get(location, allow_redirects=True)
     open(loc, 'wb').write(r.content)

# Unzip zip file to datasets folder

import zipfile
zip_ref = zipfile.ZipFile('datasets.zip', 'r')
zip_ref.extractall('')
zip_ref.close()

# %%
import pandas as pd

# %%
location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# ...

# %%
df["PRICE"]<100000
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20         True
# 21        False
# 22        False
# 23        False
# 24        False
# 25         True
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
df[BEDRM]=4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5c7e64c4a71e> in <module>()
# ----> 1 df[BEDRM]==4
#
# NameError: name 'BEDRM' is not defined

# %%
df[(df["PRICE"]<100000) & (df["BEDRM"]=4)]

# %%
(df["PRICE"]<100000)& (df["EYB"] > 2010)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
df[(df["PRICE"]<100000)& df["EYB"] > 2010)["ROOMS"].mean()
# Out:
#   File "<ipython-input-14-2b2178eb1d58>", line 1
#     df[(df["PRICE"]<100000)& df["EYB"] > 2010)["ROOMS"].mean()
#                                              ^
# SyntaxError: invalid syntax

# %%
(df["ZIPCODE"]==20001) & (df["CNDTN"]== "Fair")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#make a scatterplot
sns.lmplot(x='BEDRM', y='AYB', data=df)

# %%
#boxplot showing stats for each characteristic
sns.boxplot(data=df)

# %%
#use two columns to groupby
df.groupby(['BEDRM', 'EYB']).mean()
# Out:
#                Unnamed: 0     BATHRM  HF_BATHRM  NUM_UNITS      ROOMS  \
# BEDRM EYB
# 0     1875  132125.000000   1.000000   0.000000        NaN   2.000000
#       1885  126566.020408   1.000000   0.000000        NaN   2.020408
#       1890  121871.318182   1.000000   0.000000        NaN   2.409091
#       1891  120255.915033   1.000000   0.000000        NaN   2.000000
#       1895  130227.541667   1.000000   0.000000        NaN   2.000000
#       1900  134613.169014   0.985915   0.028169        0.0   2.000000
#       1902  137479.928571   1.000000   0.000000        NaN   2.000000
#       1903  142879.500000   1.000000   0.000000        NaN   2.000000
#       1905  126508.000000   1.000000   0.000000        NaN   2.000000
#       1906  148585.000000   1.000000   0.000000        NaN   2.000000
#       1907  116916.000000   1.000000   0.000000        NaN   2.000000
#       1908  124296.708333   1.000000   0.083333        NaN   2.083333
# ...

# %%
pd.pivot_table(df, values=['BEDRM'], index=['AYB'])
# Out:
#            BEDRM
# AYB
# 1754.0  6.500000
# 1765.0  2.000000
# 1776.0  3.333333
# 1780.0  2.000000
# 1782.0  3.000000
# 1784.0  4.000000
# 1785.0  2.000000
# 1787.0  8.000000
# 1788.0  4.000000
# 1790.0  3.666667
# 1791.0  4.000000
# 1793.0  4.000000
# 1794.0  4.000000
# 1795.0  6.000000
# 1796.0  4.500000
# 1797.0  9.000000
# 1799.0  5.000000
# 1800.0  2.318182
# 1801.0  5.250000
# 1802.0  3.500000
# 1803.0  2.500000
# 1805.0  6.111111
# 1806.0  2.000000
# 1807.0  5.000000
# 1808.0  3.000000
# 1810.0  4.000000
# 1811.0  3.500000
# 1812.0  2.666667
# 1813.0  2.500000
# 1815.0  3.222222
# ...          ...
# 1990.0  2.545775
# 1991.0  1.737179
# 1992.0  3.741935
# 1993.0  3.902439
# 1994.0  3.319820
# 1995.0  3.134615
# 1996.0  3.384058
# 1997.0  3.006024
# 1998.0  2.137584
# 1999.0  2.965079
# 2000.0  2.488304
# 2001.0  3.101083
# 2002.0  2.171737
# 2003.0  2.047546
# 2004.0  1.675460
# 2005.0  1.623486
# 2006.0  1.729074
# 2007.0  1.927543
# 2008.0  2.151386
# 2009.0  2.297940
# ...

# %%
#boxplot showing stats for each characteristic
sns.boxplot(data=df)

# %%
#create a dataframe containing the stats for each Pokemon
#drop Total, Stage, and Legendary
stats_df = df.drop(['BEDRM', 'AYB', ], axis=1)
stats_df.head()
# Out:
#             Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# PRICE
#  1095000.0           0       4          0      Warm Cool  Y        2.0      8
# NaN                  1       3          1      Warm Cool  Y        2.0     11
#  2100000.0           2       3          1  Hot Water Rad  Y        2.0      9
#  1602000.0           3       3          1  Hot Water Rad  Y        2.0      8
# NaN                  4       2          1      Warm Cool  Y        1.0     11
#
#             YR_RMDL   EYB  STORIES   ...     LONGITUDE ASSESSMENT_NBHD  \
# PRICE                                ...
#  1095000.0   1988.0  1972      3.0   ...    -77.040832      Old City 2
# NaN          2007.0  1972      3.0   ...    -77.040764      Old City 2
#  2100000.0   2009.0  1984      3.0   ...    -77.040678      Old City 2
#  1602000.0   2003.0  1984      3.0   ...    -77.040629      Old City 2
# NaN          2012.0  1985      3.0   ...    -77.039361      Old City 2
#
# ...
