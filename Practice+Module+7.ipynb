# %%
#Practice module 7 material

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn

# %matplotlib inline

# %%
location = "datasets/datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
#show the column names in the dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#show the data type of each column
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
#number of non-NA values
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
dupe = df.duplicated() #creates list of True/False values
df[dupe] #shows rows where duplicated is True
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
#drops duplicate rows, default is to keep first observation
df.drop_duplicates()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
#Create a new dataframe with only the data that I want to consider 
df2 = df[["PRICE","ROOMS","BEDRM","BATHRM","HF_BATHRM","KITCHENS","NUM_UNITS","SALE_NUM","GBA","AYB","ZIPCODE","LATITUDE","LONGITUDE"]]
df2.head()
# Out:
#        PRICE  ROOMS  BEDRM  BATHRM  HF_BATHRM  KITCHENS  NUM_UNITS  SALE_NUM  \
# 0  1095000.0      8      4       4          0       2.0        2.0         1
# 1        NaN     11      5       3          1       2.0        2.0         1
# 2  2100000.0      9      5       3          1       2.0        2.0         3
# 3  1602000.0      8      5       3          1       2.0        2.0         1
# 4        NaN     11      3       2          1       1.0        1.0         1
#
#       GBA     AYB  ZIPCODE   LATITUDE  LONGITUDE
# 0  2522.0  1910.0  20009.0  38.914680 -77.040832
# 1  2567.0  1898.0  20009.0  38.914683 -77.040764
# 2  2522.0  1910.0  20009.0  38.914684 -77.040678
# 3  2484.0  1900.0  20009.0  38.914683 -77.040629
# 4  5255.0  1913.0  20009.0  38.914383 -77.039361

# %%
# Check for missing data in your dependent variable; drop rows with missing data in your dependent variable

# %%
df_no_missing = df.dtypes

# %%
#drop rows with any missing data
df_no_missing = df.dropna()
df_no_missing
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
dupe = df2.duplicated() #creates list of True/False values
df[dupe] #shows rows where duplicated is True
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM            HEAT AC  NUM_UNITS  ROOMS  \
# 9050          9050       1          0      Forced Air  Y        1.0      4
# 18287        18287       1          0   Hot Water Rad  N        1.0      6
# 20204        20204       1          1  Gravity Furnac  N        1.0      6
# 25807        25807       0          0   Hot Water Rad  N        0.0      0
# 31975        31975       2          1       Warm Cool  Y        1.0      6
# 75079        75079       4          0   Hot Water Rad  N        4.0     16
# 82988        82988       3          1      Forced Air  Y        1.0      6
# 83556        83556       3          0      Forced Air  Y        1.0      6
# 92494        92494       3          1      Forced Air  Y        1.0      8
# 98932        98932       2          0       Warm Cool  Y        2.0      6
# 98933        98933       2          0       Warm Cool  Y        2.0      6
# ...

# %%
#drops duplicate rows, default is to keep first observation
df2.drop_duplicates()
# Out:
#             PRICE  ROOMS  BEDRM  BATHRM  HF_BATHRM  KITCHENS  NUM_UNITS  \
# 0       1095000.0      8      4       4          0       2.0        2.0
# 1             NaN     11      5       3          1       2.0        2.0
# 2       2100000.0      9      5       3          1       2.0        2.0
# 3       1602000.0      8      5       3          1       2.0        2.0
# 4             NaN     11      3       2          1       1.0        1.0
# 5       1950000.0     10      5       3          2       1.0        1.0
# 6             NaN      5      2       1          0       2.0        2.0
# 7       1050000.0      8      4       3          1       2.0        2.0
# 8       1430000.0      7      3       3          1       2.0        2.0
# 9             NaN      6      2       1          1       1.0        1.0
# 10            NaN     12      5       3          0       3.0        3.0
# 11            NaN     16      6       5          0       3.0        3.0
# ...

# %%
from sklearn.linear_model import LinearRegression

X = df2.drop('PRICE', axis = 1)
price = df2[['PRICE']]

# %%
X.head()
# Out:
#    ROOMS  BEDRM  BATHRM  HF_BATHRM  KITCHENS  NUM_UNITS  SALE_NUM     GBA  \
# 0      8      4       4          0       2.0        2.0         1  2522.0
# 1     11      5       3          1       2.0        2.0         1  2567.0
# 2      9      5       3          1       2.0        2.0         3  2522.0
# 3      8      5       3          1       2.0        2.0         1  2484.0
# 4     11      3       2          1       1.0        1.0         1  5255.0
#
#       AYB  ZIPCODE   LATITUDE  LONGITUDE
# 0  1910.0  20009.0  38.914680 -77.040832
# 1  1898.0  20009.0  38.914683 -77.040764
# 2  1910.0  20009.0  38.914684 -77.040678
# 3  1900.0  20009.0  38.914683 -77.040629
# 4  1913.0  20009.0  38.914383 -77.039361

# %%
price.head()
# Out:
#        PRICE
# 0  1095000.0
# 1        NaN
# 2  2100000.0
# 3  1602000.0
# 4        NaN

# %%
#assign linear regression function to a variable
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# #### Important functions to keep in mind while fitting a linear regression model are:
#
# •lm.fit() -> fits a linear model
#
#
# •lm.predict() -> Predict Y using the linear model with estimated coefficients
#
#
# •lm.score() -> Returns the coefficient of determination (R^2). A measure of how well observed outcomes are replicated by the model, as the proportion of total variation of outcomes explained by the model.

# %%
lm.fit(X, price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-41ed40fefd93> in <module>()
# ----> 1 lm.fit(X, price)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
lm.fit(X, PRICE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-77d2f11edf83> in <module>()
# ----> 1 lm.fit(X, "PRICE")
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
print('Estimated intercept coefficient:', lm.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-d9cfc8f2d065> in <module>()
# ----> 1 print('Estimated intercept coefficient:', lm.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'
